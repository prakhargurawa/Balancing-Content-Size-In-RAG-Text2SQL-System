# %% [markdown]
# #### Use Case Summary
# - Average DCG: Measures ranking quality.
# - Average Std Dev: Measures the system's score variability.
# - Average Range: Measures how strongly scores are differentiated.

# %% [markdown]
# ### Plot average range of RAG scores over spider data

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Avg range
data = [0.3012003570339113,0.29525945009210347,0.28844050936639226,0.2939084876064465,
       0.3472085368815649,0.3468805410600007,0.3468805410600007]

# Create a DataFrame for Seaborn
import pandas as pd
df = pd.DataFrame({'Index': [1,2,3,4,5,6,7], 'Value': data})

# Plot the line chart
plt.figure(figsize=(8, 6))  # Set figure size for better readability
sns.lineplot(data=df, x='Index', y='Value', marker='o', color='royalblue', linewidth=2, markersize=8)

# Change background color of the plot area (inside the plot)
plt.gca().set_facecolor('#FFF8E1')  # Lighter and brighter cream color

# Enhance graph appearance
plt.title('Average Range Pattern over data', fontsize=14, fontweight='bold')
plt.xlabel('Spider-Data', fontsize=12)
plt.ylabel('Avg. Range', fontsize=12)
plt.ylim(min(data) - 0.02, max(data) + 0.02)  # Extend y-axis to add padding around min and max values
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)  # Add grid lines with light dashed lines for better readability

# Save the plot to a specific location
save_path = 'C:\Research-Paper\PAPER-WORK-2024\Outputs\Rag-Score-Analysis\plot-avg-range.png'
plt.savefig(save_path, bbox_inches='tight', dpi=300)  # Saves the plot with high resolution

# Show the plot
plt.show()

# %% [markdown]
# ### Plot average std dev of RAG scores over spider data

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Avg std dev
data = [0.12954956215459434,0.12698008703940142,0.12392405815676047,0.12624976094967516,
       0.14968223028322972,0.14951154245470852,0.14951154245470852]

# Create a DataFrame for Seaborn
import pandas as pd
df = pd.DataFrame({'Index': [1,2,3,4,5,6,7], 'Value': data})

# Plot the line chart
plt.figure(figsize=(8, 6))  # Set figure size for better readability
sns.lineplot(data=df, x='Index', y='Value', marker='o', color='royalblue', linewidth=2, markersize=8)

# Change background color of the plot area (inside the plot)
plt.gca().set_facecolor('#FFF8E1')  # Lighter and brighter cream color

# Enhance graph appearance
plt.title('Average Std Dev Pattern over data', fontsize=14, fontweight='bold')
plt.xlabel('Spider-Data', fontsize=12)
plt.ylabel('Avg. Std Dev', fontsize=12)
plt.ylim(min(data) - 0.02, max(data) + 0.02)  # Extend y-axis to add padding around min and max values
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)  # Add grid lines with light dashed lines for better readability

# Save the plot to a specific location
save_path = 'C:\Research-Paper\PAPER-WORK-2024\Outputs\Rag-Score-Analysis\plot-avg-std-dev.png'
plt.savefig(save_path, bbox_inches='tight', dpi=300)  # Saves the plot with high resolution

# Show the plot
plt.show()

# %% [markdown]
# ### Plot average DCG Score of RAG scores over spider data
#
# If you're comparing DCG values between systems, a higher DCG score generally indicates a better ranking of relevant documents. So, if System 2 has a higher DCG than System 1, you can infer that System 2 ranks more relevant documents higher.
#
# But here instead pf score we used the score provided by rag system so avg DCG lower is better.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Avg std dev
data = [2.8293474608845566,2.8791333707959486,2.8393276740580395,2.769098831128947,
        2.3993337856854504,2.3983041892067205,2.3983041892067205]

# Create a DataFrame for Seaborn
import pandas as pd
df = pd.DataFrame({'Index': [1,2,3,4,5,6,7], 'Value': data})

# Plot the line chart
plt.figure(figsize=(8, 6))  # Set figure size for better readability
sns.lineplot(data=df, x='Index', y='Value', marker='o', color='royalblue', linewidth=2, markersize=8)

# Change background color of the plot area (inside the plot)
plt.gca().set_facecolor('#FFF8E1')  # Lighter and brighter cream color

# Enhance graph appearance
plt.title('Average DCG Pattern over data', fontsize=14, fontweight='bold')
plt.xlabel('Spider-Data', fontsize=12)
plt.ylabel('Avg. DCG', fontsize=12)
plt.ylim(min(data) - 0.5, max(data) + 0.5)  # Extend y-axis to add padding around min and max values
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)  # Add grid lines with light dashed lines for better readability

# Save the plot to a specific location
save_path = 'C:\Research-Paper\PAPER-WORK-2024\Outputs\Rag-Score-Analysis\plot-avg-dcg.png'
plt.savefig(save_path, bbox_inches='tight', dpi=300)  # Saves the plot with high resolution

# Show the plot
plt.show()
